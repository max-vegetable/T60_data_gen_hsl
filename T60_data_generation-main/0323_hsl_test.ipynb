# %%
import torch

# %%
data = torch.load("/data2/hsl/0323_pt_data/add_with_zky_0316/train/Cas-YanXiHu/Cas-YanXiHu_230-first-dot_Cas-YanXiHu_粤语女声_6_TIMIT_b109_140_150_20dB-0.pt")

# %%
data.keys()
# Out:
# dict_keys(['Cas-YanXiHu_230-first-dot_Cas-YanXiHu_粤语女声_6_TIMIT_b109_140_150_20dB-0'])

# %%
data = data['Cas-YanXiHu_230-first-dot_Cas-YanXiHu_粤语女声_6_TIMIT_b109_140_150_20dB-0']

# %%
len(data)
# Out:
# 5

# %%
x = data[0]
x
# Out:
# {'image': [tensor([[-102.6868, -110.7553, -103.0147,  ..., -101.0923, -120.8554,
#            -101.9840],
#           [ -99.6714, -107.5532,  -99.9971,  ...,  -98.0671, -117.7242,
#             -98.8602],
#           [ -99.6560, -107.0220,  -99.9752,  ...,  -98.0227, -117.3781,
#             -98.5357],
#           ...,
#           [  -2.3506,   -6.6204,   15.8307,  ...,   26.6129,   13.0020,
#              18.6609],
#           [  -4.4603,   -0.1783,   17.7219,  ...,   28.7346,   19.7680,
#              22.9433],
#           [  -0.5644,   -6.4584,   15.1762,  ...,   24.2052,   16.1054,
#              19.7629]], dtype=torch.float64),
#   tensor([[-112.2703, -106.0719,  -84.5890,  ...,  -90.9885,  -93.4304,
#            -115.0260],
#           [-109.2507,  -96.5256,  -81.5710,  ...,  -87.7890,  -90.4002,
#            -105.3481],
#           [-109.2230,  -91.2877,  -81.5479,  ...,  -87.2641,  -90.3406,
#            -100.0713],
#           ...,
# ...

# %%
x.keys()
# Out:
# dict_keys(['image', 'ddr', 't60', 'MeanT60'])

# %%
x['t60']
# Out:
# tensor([0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.1600, 0.0000,
#         0.0000, 1.1200, 0.0000, 0.0000, 1.2400, 0.0000, 0.0000, 1.2900, 0.0000,
#         0.0000, 1.2900, 0.0000, 0.0000, 1.1000, 0.0000, 0.0000, 0.6900, 0.0000,
#         0.0000, 0.0000, 0.0000], dtype=torch.float64)

# %%
x['image'][2].shape
# Out:
# torch.Size([129, 43])

# %%
# Out:
# torch.Size([129, 21])

# %%
import matplotlib.pyplot as plt
plt.imshow(y[4])

# %%
# -*- coding: utf-8 -*-
"""
@file      :  1130_thread_gen.py
@Time      :  2022/11/30 18:48
@Software  :  PyCharm
@summary   :
@Author    :  Bajian Xiang
"""

# nohup python 0831_thread_gen_1khz.py  >> /mnt/sda/xbj/thread_0831_gen_data.log 2>&1 &

import datetime
import os
import threading


def execCmd(cmd):
    try:
        print("COMMAND -- %s -- BEGINS -- %s -- " % (cmd, datetime.datetime.now()))
        os.system(cmd)
        print("COMMAND -- %s -- ENDS -- %s -- " % (cmd, datetime.datetime.now()))
    except:
        print("Failed -- %s -- " % cmd)


# 如果只是路径变了的话，就改这3个地方
# Don't forget the last '/' in those paths!!!!
# Carefully check!!!

dir_str_head = "/data2/xbj/0224_testdata/雁栖湖/"  # 虽然这个名字是2k，但实际上是1khz的数据
save_dir_head = "/data2/hsl/pt_generate/0320_yanqihu_500hz/"
csv_path = "/mnt/sda/xbj/1000Hz.csv"  # 新传上去了

dir_str_ = [dir_str_head + "101",
           dir_str_head + "127",
           dir_str_head + "134",
           dir_str_head + "207",
           dir_str_head + "209",
           dir_str_head + "213",
           dir_str_head + "215",
           dir_str_head + "219",
           dir_str_head + "223",
           dir_str_head + "227",
           dir_str_head + "230",
           dir_str_head + "232",
           ]

save_dir_ = [save_dir_head + "101",
            save_dir_head + "127",
            save_dir_head + "134",
            save_dir_head + "207",
            save_dir_head + "209",
            save_dir_head + "213",
            save_dir_head + "215",
            save_dir_head + "219",
            save_dir_head + "223",
            save_dir_head + "227",
            save_dir_head + "230",
            save_dir_head + "232",
            ]
#如果文件夹不存在，创立空文件夹
'''
for i in range(len(dir_str_)):
    if(os.path.exists(save_dir_[i]) == False):
       os.mkdir(save_dir_[i])
'''

#获取所有含音频文件的目录
dir_str = []
save_dir = []
for i in range(len(dir_str_)):
    temp1 = os.listdir(dir_str_[i])

    for j in range(len(temp1)):
        dir_str.append((dir_str_[i] +'/' +temp1[j] ))
        #save_dir.append((save_dir_[i] +'/' +temp1[j] ))

'''
for i in range(len(save_dir)):
    if(os.path.exists(save_dir[i]) == False):
       os.mkdir(save_dir[i])
'''


print(dir_str)
print('*'*10)
print(save_dir)
# Out:
# ['/data2/xbj/0224_testdata/雁栖湖/101/第三个测点', '/data2/xbj/0224_testdata/雁栖湖/101/.DS_Store', '/data2/xbj/0224_testdata/雁栖湖/101/第二个测点', '/data2/xbj/0224_testdata/雁栖湖/101/第五个测点', '/data2/xbj/0224_testdata/雁栖湖/101/第一个测点', '/data2/xbj/0224_testdata/雁栖湖/101/第四个测点', '/data2/xbj/0224_testdata/雁栖湖/127/.DS_Store', '/data2/xbj/0224_testdata/雁栖湖/127/第二个测点', '/data2/xbj/0224_testdata/雁栖湖/127/第一个测点', '/data2/xbj/0224_testdata/雁栖湖/134/.DS_Store', '/data2/xbj/0224_testdata/雁栖湖/134/第二个测点', '/data2/xbj/0224_testdata/雁栖湖/134/第一个测点', '/data2/xbj/0224_testdata/雁栖湖/207/第三个测点', '/data2/xbj/0224_testdata/雁栖湖/207/.DS_Store', '/data2/xbj/0224_testdata/雁栖湖/207/第二个测点', '/data2/xbj/0224_testdata/雁栖湖/207/第五个测点', '/data2/xbj/0224_testdata/雁栖湖/207/第一个测点', '/data2/xbj/0224_testdata/雁栖湖/207/第四个测点', '/data2/xbj/0224_testdata/雁栖湖/209/第三个测点', '/data2/xbj/0224_testdata/雁栖湖/209/.DS_Store', '/data2/xbj/0224_testdata/雁栖湖/209/第二个测点', '/data2/xbj/0224_testdata/雁栖湖/209/第五个测点', '/data2/xbj/0224_testdata/雁栖湖/209/第一个测点', '/data2/xbj
# ...

# %%
COMMAND -- python 0921_OurData_GenPT.py --dir_str /data2/hsl/0323_wav_data/add_without_zky_0316/Speech/koli-national-park-summer --save_dir /data2/hsl/0323_pt_data/add_without_zky_0316/train/koli-national-park-summer --csv_file /data2/hsl/0323_wav_data/add_without_zky_0316/Speech/koli-national-park-summer/20230321T124743_test_gen_corpus_dataset_results.csv
COMMAND -- python 0921_OurData_GenPT.py --dir_str /data2/hsl/0323_wav_data/add_without_zky_0316/Speech/hoffmann-lime-kiln-langcliffeuk --save_dir /data2/hsl/0323_pt_data/add_without_zky_0316/train/hoffmann-lime-kiln-langcliffeuk --csv_file /data2/hsl/0323_wav_data/add_without_zky_0316/Speech/hoffmann-lime-kiln-langcliffeuk/20230321T124743_test_gen_corpus_dataset_results.csv
COMMAND -- python 0921_OurData_GenPT.py --dir_str /data2/hsl/0323_wav_data/add_without_zky_0316/Speech/koli-national-park-winter --save_dir /data2/hsl/0323_pt_data/add_without_zky_0316/train/koli-national-park-winter --csv_file /data2/hsl/0323_wav_data/add_without_zky_0316/Speech/koli-national-park-winter/20230321T124743_test_gen_corpus_dataset_results.csv
COMMAND -- python 0921_OurData_GenPT.py --dir_str /data2/hsl/0323_wav_data/add_without_zky_0316/Speech/gill-heads-mine --save_dir /data2/hsl/0323_pt_data/add_without_zky_0316/train/gill-heads-mine --csv_file /data2/hsl/0323_wav_data/add_without_zky_0316/Speech/gill-heads-mine/20230321T124743_test_gen_corpus_dataset_results.csv
COMMAND -- python 0921_OurData_GenPT.py --dir_str /data2/hsl/0323_wav_data/add_without_zky_0316/Speech/innocent-railway-tunnel --save_dir /data2/hsl/0323_pt_data/add_without_zky_0316/train/innocent-railway-tunnel --csv_file /data2/hsl/0323_wav_data/add_without_zky_0316/Speech/innocent-railway-tunnel/20230321T124743_test_gen_corpus_dataset_results.csv
COMMAND -- python 0921_OurData_GenPT.py --dir_str /data2/hsl/0323_wav_data/add_without_zky_0316/Speech/dixon-studio-theatre-university-york --save_dir /data2/hsl/0323_pt_data/add_without_zky_0316/train/dixon-studio-theatre-university-york --csv_file /data2/hsl/0323_wav_data/add_without_zky_0316/Speech/dixon-studio-theatre-university-york/20230321T124743_test_gen_corpus_dataset_results.csv
COMMAND -- python 0921_OurData_GenPT.py --dir_str /data2/hsl/0323_wav_data/add_without_zky_0316/Speech/york-guildhall-council-chamber --save_dir /data2/hsl/0323_pt_data/add_without_zky_0316/train/york-guildhall-council-chamber --csv_file /data2/hsl/0323_wav_data/add_without_zky_0316/Speech/york-guildhall-council-chamber/20230321T124743_test_gen_corpus_dataset_results.csv

# %%
nohup python 0921_OurData_GenPT.py --dir_str /data2/hsl/0323_wav_data/add_without_zky_0316/Speech/central-hall-university-york/ --save_dir /data2/hsl/0323_pt_data/add_without_zky_0316/train/central-hall-university-york/ --csv_file /data2/hsl/0323_wav_data/add_without_zky_0316/Speech/central-hall-university-york/20230321T124743_test_gen_corpus_dataset_results.csv >> /data2/hsl/0324_central-hall-university-york.log 2>&1 &

# %%
import torch
clean = torch.load("/data2/hsl/0324_clean_pt/长沙话女声_1.pt")
data = torch.load("/data/xbj/0927_500hz_with_clean/train/arthur-sykes-rymer-auditorium-university-york/arthur-sykes-rymer-auditorium-university-york_s1r2_3_arthur-sykes-rymer-auditorium-university-york_长沙话女声_1_TIMIT_a019_40_50_0dB-0.pt")

# %%
clean = clean['长沙话女声_1']
data = data['arthur-sykes-rymer-auditorium-university-york_s1r2_3_arthur-sykes-rymer-auditorium-university-york_长沙话女声_1_TIMIT_a019_40_50_0dB-0']

# %%
len(clean)
len(data)
# Out:
# 4

# %%
d1 = data[0]['clean']
d1.dtype
# Out:
# dtype('float64')

# %%
c1 = clean[0]['image'][2]
c1
# Out:
# tensor([[-159.2857, -152.5572, -160.6681,  ..., -164.3089, -165.4089,
#          -151.5140],
#         [-149.6078, -146.5225, -147.8387,  ..., -152.0343, -151.7363,
#          -146.5403],
#         [-144.3500, -142.5317, -142.1683,  ..., -146.4152, -146.0014,
#          -143.3334],
#         ...,
#         [ -36.0087,  -33.5329,  -33.7607,  ...,  -34.3737,  -40.7002,
#           -39.9705],
#         [   6.3805,    7.0739,    7.8653,  ...,    4.1453,    4.6461,
#             5.1630],
#         [   9.3403,   10.0333,   10.8432,  ...,    7.1018,    7.6034,
#             8.1201]], dtype=torch.float64)

# %%
c1 == d1
# Out:
# False

# %%
import matplotlib.pyplot as plt
plt.imshow(c1)

# %%
plt.imshow(d1)

# %%
x1 = torch.load("/data/xbj/0927_500hz_with_clean/train/koli-national-park-winter/koli-national-park-winter_koli_snow_site4_1way_bformat_1_koli-national-park-winter_东北话男声_1_TIMIT_a074_40_50_0dB-0.pt")
x2 = torch.load("/data2/hsl/0324_pt_with_clean/Cas-YanXiHu/Cas-YanXiHu_230-first-dot_Cas-YanXiHu_美语女声_1_TIMIT_a098_180_190_20dB-0.pt")

# %%
x1 = x1['koli-national-park-winter_koli_snow_site4_1way_bformat_1_koli-national-park-winter_东北话男声_1_TIMIT_a074_40_50_0dB-0']
x2 = x2['Cas-YanXiHu_230-first-dot_Cas-YanXiHu_美语女声_1_TIMIT_a098_180_190_20dB-0']

# %%
x1[0]['t60']
# Out:
# tensor([0.0000, 0.0855, 0.0000, 0.0000, 0.1120, 0.0000, 0.0000, 0.1110, 0.0000,
#         0.0000, 0.3925, 0.0000, 0.0000, 0.7980, 0.0000, 0.0000, 0.7845, 0.0000,
#         0.0000, 0.6405, 0.0000, 0.0000, 0.4270, 0.0000, 0.0000, 0.2620, 0.0000,
#         0.0000, 0.1655, 0.0000], dtype=torch.float64)

# %%
x2[0]['t60']
# Out:
# tensor([0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 1.1600, 0.0000,
#         0.0000, 1.1200, 0.0000, 0.0000, 1.2400, 0.0000, 0.0000, 1.2900, 0.0000,
#         0.0000, 1.2900, 0.0000, 0.0000, 1.1000, 0.0000, 0.0000, 0.6900, 0.0000,
#         0.0000, 0.0000, 0.0000], dtype=torch.float64)

# %%
torch.unsqueeze(x2[0]['t60'][13], 0)
# Out:
# tensor([1.2400], dtype=torch.float64)
